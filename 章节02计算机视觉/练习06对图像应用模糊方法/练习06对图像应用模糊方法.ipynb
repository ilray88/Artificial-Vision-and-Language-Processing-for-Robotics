# %% [markdown]
# # 练习06对图像应用模糊方法

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# ####

# %%
# cd /content/drive/My Drive/C13550/Lesson02/Exercise03/

# %% [markdown]
# ####

# %%
import cv2
from matplotlib import pyplot as plt
import numpy as np

# %% [markdown]
# ####

# %%
img = cv2.imread('subway.jpg')
#Method to convert the image to RGB
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.savefig('ex3_1.jpg', bbox_inches='tight')
plt.xticks([]),plt.yticks([])
plt.show()

# %% [markdown]
# ####

# %%
blur = cv2.blur(img,(51,51))
blurG = cv2.GaussianBlur(img,(51,51),0)
median = cv2.medianBlur(img,51)
blur = cv2.blur(img,(51,51))
blurG = cv2.GaussianBlur(img,(51,51),0)
median = cv2.medianBlur(img,51)
titles = ['Original Image','Averaging', 'Gaussian Blurring', 'Median Blurring']
images = [img, blur, blurG, median]

for i in range(4):
    plt.subplot(2,2,i+1),plt.imshow(images[i])
    plt.title(titles[i])
    plt.xticks([]),plt.yticks([])
plt.savefig('ex3_2.jpg', bbox_inches='tight')

plt.show()

# %% [markdown]
# ####
